# %%
import pandas as pd
raw_data = pd.read_csv('github_bot_raw_data.csv') 
#列字段解读
columns = [
    'actor_id',  # GitHub用户的ID (示例值: 1081405)
    'label',  # 用户标签（"Human"或"Bot"） (示例值: Human)
    'login',  # GitHub用户的登录名 (示例值: dlazesz)
    'id',  # 用户的GitHub ID (示例值: 1081405)
    'node_id',  # 用户的GitHub节点ID (示例值: MDQ6VXNlcjEwODE0MDU=)
    'avatar_url',  # GitHub头像URL (示例值: https://avatars.githubusercontent.com/u/1081405?v=4)
    'gravatar_id',  # Gravatar ID (示例值: None)
    'url',  # GitHub用户的URL (示例值: https://api.github.com/users/dlazesz)
    'html_url',  # GitHub用户的HTML URL (示例值: https://github.com/dlazesz)
    'followers_url',  # GitHub用户的粉丝URL (示例值: https://api.github.com/users/dlazesz/followers)
    'following_url',  # GitHub用户的关注URL (示例值: https://api.github.com/users/dlazesz/following{/other_user})
    'gists_url',  # 用户的GitHub Gists URL (示例值: https://api.github.com/users/dlazesz/gists{/gist_id})
    'starred_url',  # 用户的GitHub Starred URL (示例值: https://api.github.com/users/dlazesz/starred{/owner}{/repo})
    'subscriptions_url',  # 用户的GitHub订阅URL (示例值: https://api.github.com/users/dlazesz/subscriptions)
    'organizations_url',  # 用户的GitHub组织URL (示例值: https://api.github.com/users/dlazesz/orgs)
    'repos_url',  # 用户的GitHub仓库URL (示例值: https://api.github.com/users/dlazesz/repos)
    'events_url',  # 用户的GitHub事件URL (示例值: https://api.github.com/users/dlazesz/events{/privacy})
    'received_events_url',  # 用户的GitHub接收事件URL (示例值: https://api.github.com/users/dlazesz/received_events)
    'type',  # 用户类型，通常为"User" (示例值: User)
    'site_admin',  # 表示用户是否是GitHub网站管理员的标志 (示例值: False)
    'name',  # 用户的姓名 (示例值: Indig Balázs)
    'company',  # 用户所在公司 (示例值: None)
    'blog',  # 用户的博客 (示例值: None)
    'location',  # 用户的位置 (示例值: None)
    'email',  # 用户的电子邮件 (示例值: None)
    'hireable',  # 表示用户是否愿意被雇佣的标志 (示例值: None)
    'bio',  # 用户在其GitHub资料中提供的自我介绍或个人简介 (示例值: None)
    'twitter_username',  # 用户的Twitter用户名 (示例值: None)
    'public_repos',  # 用户在GitHub上的公共代码仓库数量 (示例值: 26)
    'public_gists',  # 用户的公共Gists数量 (示例值: 1)
    'followers',  # 关注该用户的其他GitHub用户数量 (示例值: 5)
    'following',  # 该用户关注的其他GitHub用户数量 (示例值: 1)
    'created_at',  # 用户的GitHub帐户创建日期 (示例值: 2011-09-26T17:27:03Z)
    'updated_at',  # 用户的GitHub帐户最后更新日期 (示例值: 2023-10-13T11:21:10Z)
]
data = raw_data[columns]

data1=data.drop_duplicates()
print("处理前：",len(data))
print("处理后：",len(data1))
# Out:
# 处理前： 20358
# 处理后： 19779

# %%
#列字段解读
columns = [
    'actor_id',  # GitHub用户的ID (示例值: 1081405)
    'label',  # 用户标签（"Human"或"Bot"） (示例值: Human)
    'login',  # GitHub用户的登录名 (示例值: dlazesz)
    'id',  # 用户的GitHub ID (示例值: 1081405)
    'node_id',  # 用户的GitHub节点ID (示例值: MDQ6VXNlcjEwODE0MDU=)
    'avatar_url',  # GitHub头像URL (示例值: https://avatars.githubusercontent.com/u/1081405?v=4)
    #'gravatar_id',  # Gravatar ID (示例值: None)
    'url',  # GitHub用户的URL (示例值: https://api.github.com/users/dlazesz)
    'html_url',  # GitHub用户的HTML URL (示例值: https://github.com/dlazesz)
    'followers_url',  # GitHub用户的粉丝URL (示例值: https://api.github.com/users/dlazesz/followers)
    'following_url',  # GitHub用户的关注URL (示例值: https://api.github.com/users/dlazesz/following{/other_user})
    'gists_url',  # 用户的GitHub Gists URL (示例值: https://api.github.com/users/dlazesz/gists{/gist_id})
    'starred_url',  # 用户的GitHub Starred URL (示例值: https://api.github.com/users/dlazesz/starred{/owner}{/repo})
    'subscriptions_url',  # 用户的GitHub订阅URL (示例值: https://api.github.com/users/dlazesz/subscriptions)
    'organizations_url',  # 用户的GitHub组织URL (示例值: https://api.github.com/users/dlazesz/orgs)
    'repos_url',  # 用户的GitHub仓库URL (示例值: https://api.github.com/users/dlazesz/repos)
    'events_url',  # 用户的GitHub事件URL (示例值: https://api.github.com/users/dlazesz/events{/privacy})
    'received_events_url',  # 用户的GitHub接收事件URL (示例值: https://api.github.com/users/dlazesz/received_events)
    'type',  # 用户类型，通常为"User" (示例值: User)
    'site_admin',  # 表示用户是否是GitHub网站管理员的标志 (示例值: False)
    'name',  # 用户的姓名 (示例值: Indig Balázs)
    'company',  # 用户所在公司 (示例值: None)
    'blog',  # 用户的博客 (示例值: None)
    'location',  # 用户的位置 (示例值: None)
    'email',  # 用户的电子邮件 (示例值: None)
    'hireable',  # 表示用户是否愿意被雇佣的标志 (示例值: None)
    'bio',  # 用户在其GitHub资料中提供的自我介绍或个人简介 (示例值: None)
    'twitter_username',  # 用户的Twitter用户名 (示例值: None)
    'public_repos',  # 用户在GitHub上的公共代码仓库数量 (示例值: 26)
    'public_gists',  # 用户的公共Gists数量 (示例值: 1)
    'followers',  # 关注该用户的其他GitHub用户数量 (示例值: 5)
    'following',  # 该用户关注的其他GitHub用户数量 (示例值: 1)
    'created_at',  # 用户的GitHub帐户创建日期 (示例值: 2011-09-26T17:27:03Z)
    'updated_at',  # 用户的GitHub帐户最后更新日期 (示例值: 2023-10-13T11:21:10Z)
]
data = raw_data[columns]

print(data)

for i in data:
    for j in i:
        if j=='True' or j=='False':
            j=bool(j)

print(data)
# Out:
#        actor_id  label      login        id               node_id  \
# 0       1081405  Human    dlazesz   1081405  MDQ6VXNlcjEwODE0MDU=
# 1      13100598  Human  sarkiroka  13100598  MDQ6VXNlcjEzMTAwNTk4
# 2         22494  Human  ZoomQuiet     22494      MDQ6VXNlcjIyNDk0
# 3       7648032    Bot   AlCutter   7648032  MDQ6VXNlcjc2NDgwMzI=
# 4       2163522  Human    meetyan   2163522  MDQ6VXNlcjIxNjM1MjI=
# ...         ...    ...        ...       ...                   ...
# 20353   8052756    Bot    tbreeds   8052756  MDQ6VXNlcjgwNTI3NTY=
# 20354  34321341  Human     ssisil  34321341  MDQ6VXNlcjM0MzIxMzQx
# 20355  15847407  Human   dbfannin  15847407  MDQ6VXNlcjE1ODQ3NDA3
# 20356  94929125  Human    jambayk  94929125          U_kgDOBaiA5Q
# 20357  18622487    Bot     G3rrus  18622487  MDQ6VXNlcjE4NjIyNDg3
#
#                                               avatar_url  \
# 0      https://avatars.githubusercontent.com/u/108140...
# 1      https://avatars.githubusercontent.com/u/131005...
# 2      https://avatars.githubusercontent.com/u/22494?v=4
# 3      https://avatars.githubusercontent.com/u/764803...
# 4      https://avatars.githubusercontent.com/u/216352...
# ...                                                  ...
# 20353  https://avatars.githubusercontent.com/u/805275...
# 20354  https://avatars.githubusercontent.com/u/343213...
# 20355  https://avatars.githubusercontent.com/u/158474...
# 20356  https://avatars.githubusercontent.com/u/949291...
# 20357  https://avatars.githubusercontent.com/u/186224...
#
#                                           url                      html_url  \
# 0        https://api.github.com/users/dlazesz    https://github.com/dlazesz
# 1      https://api.github.com/users/sarkiroka  https://github.com/sarkiroka
# 2      https://api.github.com/users/ZoomQuiet  https://github.com/ZoomQuiet
# 3       https://api.github.com/users/AlCutter   https://github.com/AlCutter
# 4        https://api.github.com/users/meetyan    https://github.com/meetyan
# ...                                       ...                           ...
# 20353    https://api.github.com/users/tbreeds    https://github.com/tbreeds
# 20354     https://api.github.com/users/ssisil     https://github.com/ssisil
# 20355   https://api.github.com/users/dbfannin   https://github.com/dbfannin
# 20356    https://api.github.com/users/jambayk    https://github.com/jambayk
# 20357     https://api.github.com/users/G3rrus     https://github.com/G3rrus
#
#                                           followers_url  \
# 0        https://api.github.com/users/dlazesz/followers
# 1      https://api.github.com/users/sarkiroka/followers
# 2      https://api.github.com/users/ZoomQuiet/followers
# 3       https://api.github.com/users/AlCutter/followers
# 4        https://api.github.com/users/meetyan/followers
# ...                                                 ...
# 20353    https://api.github.com/users/tbreeds/followers
# 20354     https://api.github.com/users/ssisil/followers
# 20355   https://api.github.com/users/dbfannin/followers
# 20356    https://api.github.com/users/jambayk/followers
# 20357     https://api.github.com/users/G3rrus/followers
#
#                                            following_url  ...  \
# 0      https://api.github.com/users/dlazesz/following...  ...
# 1      https://api.github.com/users/sarkiroka/followi...  ...
# 2      https://api.github.com/users/ZoomQuiet/followi...  ...
# 3      https://api.github.com/users/AlCutter/followin...  ...
# 4      https://api.github.com/users/meetyan/following...  ...
# ...                                                  ...  ...
# 20353  https://api.github.com/users/tbreeds/following...  ...
# 20354  https://api.github.com/users/ssisil/following{...  ...
# 20355  https://api.github.com/users/dbfannin/followin...  ...
# 20356  https://api.github.com/users/jambayk/following...  ...
# 20357  https://api.github.com/users/G3rrus/following{...  ...
#
#                             email hireable  \
# 0                             NaN      NaN
# 1                             NaN     True
# 2                             NaN     True
# 3                             NaN      NaN
# 4                             NaN     True
# ...                           ...      ...
# 20353     tony@bakeyournoodle.com      NaN
# 20354           ssisil@pivotal.io      NaN
# 20355                         NaN      NaN
# 20356  jambaykinley@microsoft.com      NaN
# 20357                         NaN      NaN
#
#                                                      bio twitter_username  \
# 0                                                    NaN              NaN
# 1      I just press the buttons randomly, and the pro...              NaN
# 2           Time is unimportant,\r\nonly life important.            zoomq
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 20353  Tony came to Linux in 1994 and has never looke...       tonybreeds
# 20354                                                NaN              NaN
# 20355                    Software engineer at RealTracs.              NaN
# 20356                                                NaN              NaN
# 20357                                                NaN              NaN
#
#       public_repos public_gists followers following            created_at  \
# 0               26            1         5         1  2011-09-26T17:27:03Z
# 1               30            3         9         6  2015-06-29T10:12:46Z
# 2              103           49      1212       221  2008-08-29T16:20:03Z
# 3               49            0        84         2  2014-05-20T18:43:09Z
# 4               11            1         6         2  2012-08-16T14:19:13Z
# ...            ...          ...       ...       ...                   ...
# 20353           36           16        11         4  2014-07-02T23:27:34Z
# 20354           16            0         3         0  2017-12-06T21:56:31Z
# 20355           13            0        10         1  2015-11-14T14:44:05Z
# 20356            7            0         2         0  2021-11-23T18:55:29Z
# 20357           10            0         1         0  2016-04-22T22:11:59Z
#
#                  updated_at
# 0      2023-10-13T11:21:10Z
# 1      2023-10-07T06:26:14Z
# 2      2023-10-02T02:11:21Z
# 3      2023-10-12T12:54:59Z
# 4      2023-10-06T11:58:41Z
# ...                     ...
# 20353  2023-08-15T16:38:34Z
# 20354  2023-07-26T18:32:25Z
# 20355  2022-08-23T21:09:49Z
# 20356  2023-10-06T22:50:45Z
# 20357  2022-07-07T19:48:21Z
#
# [20358 rows x 33 columns]
#        actor_id  label      login        id               node_id  \
# 0       1081405  Human    dlazesz   1081405  MDQ6VXNlcjEwODE0MDU=
# 1      13100598  Human  sarkiroka  13100598  MDQ6VXNlcjEzMTAwNTk4
# 2         22494  Human  ZoomQuiet     22494      MDQ6VXNlcjIyNDk0
# 3       7648032    Bot   AlCutter   7648032  MDQ6VXNlcjc2NDgwMzI=
# 4       2163522  Human    meetyan   2163522  MDQ6VXNlcjIxNjM1MjI=
# ...         ...    ...        ...       ...                   ...
# 20353   8052756    Bot    tbreeds   8052756  MDQ6VXNlcjgwNTI3NTY=
# 20354  34321341  Human     ssisil  34321341  MDQ6VXNlcjM0MzIxMzQx
# 20355  15847407  Human   dbfannin  15847407  MDQ6VXNlcjE1ODQ3NDA3
# 20356  94929125  Human    jambayk  94929125          U_kgDOBaiA5Q
# 20357  18622487    Bot     G3rrus  18622487  MDQ6VXNlcjE4NjIyNDg3
#
#                                               avatar_url  \
# 0      https://avatars.githubusercontent.com/u/108140...
# 1      https://avatars.githubusercontent.com/u/131005...
# 2      https://avatars.githubusercontent.com/u/22494?v=4
# 3      https://avatars.githubusercontent.com/u/764803...
# 4      https://avatars.githubusercontent.com/u/216352...
# ...                                                  ...
# 20353  https://avatars.githubusercontent.com/u/805275...
# 20354  https://avatars.githubusercontent.com/u/343213...
# 20355  https://avatars.githubusercontent.com/u/158474...
# 20356  https://avatars.githubusercontent.com/u/949291...
# 20357  https://avatars.githubusercontent.com/u/186224...
#
#                                           url                      html_url  \
# 0        https://api.github.com/users/dlazesz    https://github.com/dlazesz
# 1      https://api.github.com/users/sarkiroka  https://github.com/sarkiroka
# 2      https://api.github.com/users/ZoomQuiet  https://github.com/ZoomQuiet
# 3       https://api.github.com/users/AlCutter   https://github.com/AlCutter
# 4        https://api.github.com/users/meetyan    https://github.com/meetyan
# ...                                       ...                           ...
# 20353    https://api.github.com/users/tbreeds    https://github.com/tbreeds
# 20354     https://api.github.com/users/ssisil     https://github.com/ssisil
# 20355   https://api.github.com/users/dbfannin   https://github.com/dbfannin
# 20356    https://api.github.com/users/jambayk    https://github.com/jambayk
# 20357     https://api.github.com/users/G3rrus     https://github.com/G3rrus
#
#                                           followers_url  \
# 0        https://api.github.com/users/dlazesz/followers
# 1      https://api.github.com/users/sarkiroka/followers
# 2      https://api.github.com/users/ZoomQuiet/followers
# 3       https://api.github.com/users/AlCutter/followers
# 4        https://api.github.com/users/meetyan/followers
# ...                                                 ...
# 20353    https://api.github.com/users/tbreeds/followers
# 20354     https://api.github.com/users/ssisil/followers
# 20355   https://api.github.com/users/dbfannin/followers
# 20356    https://api.github.com/users/jambayk/followers
# 20357     https://api.github.com/users/G3rrus/followers
#
#                                            following_url  ...  \
# 0      https://api.github.com/users/dlazesz/following...  ...
# 1      https://api.github.com/users/sarkiroka/followi...  ...
# 2      https://api.github.com/users/ZoomQuiet/followi...  ...
# 3      https://api.github.com/users/AlCutter/followin...  ...
# 4      https://api.github.com/users/meetyan/following...  ...
# ...                                                  ...  ...
# 20353  https://api.github.com/users/tbreeds/following...  ...
# 20354  https://api.github.com/users/ssisil/following{...  ...
# 20355  https://api.github.com/users/dbfannin/followin...  ...
# 20356  https://api.github.com/users/jambayk/following...  ...
# 20357  https://api.github.com/users/G3rrus/following{...  ...
#
#                             email hireable  \
# 0                             NaN      NaN
# 1                             NaN     True
# 2                             NaN     True
# 3                             NaN      NaN
# 4                             NaN     True
# ...                           ...      ...
# 20353     tony@bakeyournoodle.com      NaN
# 20354           ssisil@pivotal.io      NaN
# 20355                         NaN      NaN
# 20356  jambaykinley@microsoft.com      NaN
# 20357                         NaN      NaN
#
#                                                      bio twitter_username  \
# 0                                                    NaN              NaN
# 1      I just press the buttons randomly, and the pro...              NaN
# 2           Time is unimportant,\r\nonly life important.            zoomq
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 20353  Tony came to Linux in 1994 and has never looke...       tonybreeds
# 20354                                                NaN              NaN
# 20355                    Software engineer at RealTracs.              NaN
# 20356                                                NaN              NaN
# 20357                                                NaN              NaN
#
#       public_repos public_gists followers following            created_at  \
# 0               26            1         5         1  2011-09-26T17:27:03Z
# 1               30            3         9         6  2015-06-29T10:12:46Z
# 2              103           49      1212       221  2008-08-29T16:20:03Z
# 3               49            0        84         2  2014-05-20T18:43:09Z
# 4               11            1         6         2  2012-08-16T14:19:13Z
# ...            ...          ...       ...       ...                   ...
# 20353           36           16        11         4  2014-07-02T23:27:34Z
# 20354           16            0         3         0  2017-12-06T21:56:31Z
# 20355           13            0        10         1  2015-11-14T14:44:05Z
# 20356            7            0         2         0  2021-11-23T18:55:29Z
# 20357           10            0         1         0  2016-04-22T22:11:59Z
#
#                  updated_at
# 0      2023-10-13T11:21:10Z
# 1      2023-10-07T06:26:14Z
# 2      2023-10-02T02:11:21Z
# 3      2023-10-12T12:54:59Z
# 4      2023-10-06T11:58:41Z
# ...                     ...
# 20353  2023-08-15T16:38:34Z
# 20354  2023-07-26T18:32:25Z
# 20355  2022-08-23T21:09:49Z
# 20356  2023-10-06T22:50:45Z
# 20357  2022-07-07T19:48:21Z
#
# [20358 rows x 33 columns]

# %%
data['created_at']= pd.to_datetime(data['created_at'])
data['updated_at']= pd.to_datetime(data['updated_at'])

print(data)
# Out:
#        actor_id  label      login        id               node_id  \
# 0       1081405  Human    dlazesz   1081405  MDQ6VXNlcjEwODE0MDU=
# 1      13100598  Human  sarkiroka  13100598  MDQ6VXNlcjEzMTAwNTk4
# 2         22494  Human  ZoomQuiet     22494      MDQ6VXNlcjIyNDk0
# 3       7648032    Bot   AlCutter   7648032  MDQ6VXNlcjc2NDgwMzI=
# 4       2163522  Human    meetyan   2163522  MDQ6VXNlcjIxNjM1MjI=
# ...         ...    ...        ...       ...                   ...
# 20353   8052756    Bot    tbreeds   8052756  MDQ6VXNlcjgwNTI3NTY=
# 20354  34321341  Human     ssisil  34321341  MDQ6VXNlcjM0MzIxMzQx
# 20355  15847407  Human   dbfannin  15847407  MDQ6VXNlcjE1ODQ3NDA3
# 20356  94929125  Human    jambayk  94929125          U_kgDOBaiA5Q
# 20357  18622487    Bot     G3rrus  18622487  MDQ6VXNlcjE4NjIyNDg3
#
#                                               avatar_url  \
# 0      https://avatars.githubusercontent.com/u/108140...
# 1      https://avatars.githubusercontent.com/u/131005...
# 2      https://avatars.githubusercontent.com/u/22494?v=4
# 3      https://avatars.githubusercontent.com/u/764803...
# 4      https://avatars.githubusercontent.com/u/216352...
# ...                                                  ...
# 20353  https://avatars.githubusercontent.com/u/805275...
# 20354  https://avatars.githubusercontent.com/u/343213...
# 20355  https://avatars.githubusercontent.com/u/158474...
# 20356  https://avatars.githubusercontent.com/u/949291...
# 20357  https://avatars.githubusercontent.com/u/186224...
#
#                                           url                      html_url  \
# 0        https://api.github.com/users/dlazesz    https://github.com/dlazesz
# 1      https://api.github.com/users/sarkiroka  https://github.com/sarkiroka
# 2      https://api.github.com/users/ZoomQuiet  https://github.com/ZoomQuiet
# 3       https://api.github.com/users/AlCutter   https://github.com/AlCutter
# 4        https://api.github.com/users/meetyan    https://github.com/meetyan
# ...                                       ...                           ...
# 20353    https://api.github.com/users/tbreeds    https://github.com/tbreeds
# 20354     https://api.github.com/users/ssisil     https://github.com/ssisil
# 20355   https://api.github.com/users/dbfannin   https://github.com/dbfannin
# 20356    https://api.github.com/users/jambayk    https://github.com/jambayk
# 20357     https://api.github.com/users/G3rrus     https://github.com/G3rrus
#
#                                           followers_url  \
# 0        https://api.github.com/users/dlazesz/followers
# 1      https://api.github.com/users/sarkiroka/followers
# 2      https://api.github.com/users/ZoomQuiet/followers
# 3       https://api.github.com/users/AlCutter/followers
# 4        https://api.github.com/users/meetyan/followers
# ...                                                 ...
# 20353    https://api.github.com/users/tbreeds/followers
# 20354     https://api.github.com/users/ssisil/followers
# 20355   https://api.github.com/users/dbfannin/followers
# 20356    https://api.github.com/users/jambayk/followers
# 20357     https://api.github.com/users/G3rrus/followers
#
#                                            following_url  ...  \
# 0      https://api.github.com/users/dlazesz/following...  ...
# 1      https://api.github.com/users/sarkiroka/followi...  ...
# 2      https://api.github.com/users/ZoomQuiet/followi...  ...
# 3      https://api.github.com/users/AlCutter/followin...  ...
# 4      https://api.github.com/users/meetyan/following...  ...
# ...                                                  ...  ...
# 20353  https://api.github.com/users/tbreeds/following...  ...
# 20354  https://api.github.com/users/ssisil/following{...  ...
# 20355  https://api.github.com/users/dbfannin/followin...  ...
# 20356  https://api.github.com/users/jambayk/following...  ...
# 20357  https://api.github.com/users/G3rrus/following{...  ...
#
#                             email hireable  \
# 0                             NaN      NaN
# 1                             NaN     True
# 2                             NaN     True
# 3                             NaN      NaN
# 4                             NaN     True
# ...                           ...      ...
# 20353     tony@bakeyournoodle.com      NaN
# 20354           ssisil@pivotal.io      NaN
# 20355                         NaN      NaN
# 20356  jambaykinley@microsoft.com      NaN
# 20357                         NaN      NaN
#
#                                                      bio twitter_username  \
# 0                                                    NaN              NaN
# 1      I just press the buttons randomly, and the pro...              NaN
# 2           Time is unimportant,\r\nonly life important.            zoomq
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 20353  Tony came to Linux in 1994 and has never looke...       tonybreeds
# 20354                                                NaN              NaN
# 20355                    Software engineer at RealTracs.              NaN
# 20356                                                NaN              NaN
# 20357                                                NaN              NaN
#
#       public_repos public_gists followers following                created_at  \
# 0               26            1         5         1 2011-09-26 17:27:03+00:00
# 1               30            3         9         6 2015-06-29 10:12:46+00:00
# 2              103           49      1212       221 2008-08-29 16:20:03+00:00
# 3               49            0        84         2 2014-05-20 18:43:09+00:00
# 4               11            1         6         2 2012-08-16 14:19:13+00:00
# ...            ...          ...       ...       ...                       ...
# 20353           36           16        11         4 2014-07-02 23:27:34+00:00
# 20354           16            0         3         0 2017-12-06 21:56:31+00:00
# 20355           13            0        10         1 2015-11-14 14:44:05+00:00
# 20356            7            0         2         0 2021-11-23 18:55:29+00:00
# 20357           10            0         1         0 2016-04-22 22:11:59+00:00
#
#                      updated_at
# 0     2023-10-13 11:21:10+00:00
# 1     2023-10-07 06:26:14+00:00
# 2     2023-10-02 02:11:21+00:00
# 3     2023-10-12 12:54:59+00:00
# 4     2023-10-06 11:58:41+00:00
# ...                         ...
# 20353 2023-08-15 16:38:34+00:00
# 20354 2023-07-26 18:32:25+00:00
# 20355 2022-08-23 21:09:49+00:00
# 20356 2023-10-06 22:50:45+00:00
# 20357 2022-07-07 19:48:21+00:00
#
# [20358 rows x 33 columns]
# C:\Users\OYC\AppData\Local\Temp\ipykernel_2564\2668106436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['created_at']= pd.to_datetime(data['created_at'])
# C:\Users\OYC\AppData\Local\Temp\ipykernel_2564\2668106436.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['updated_at']= pd.to_datetime(data['updated_at'])

# %%
import matplotlib.pyplot as plt
label=['Bot','Human']
dat=[]
res1=0
res2=0
for i in data['label']:
    if i=='Human':
        res2+=1
    elif i=='Bot':
        res1+=1
dat.append(res1)
dat.append(res2)
plt.bar(label,dat)
plt.show()

# %%
#4.1
#只有Bot和Human两个取值统计数量，柱状图直观，可视化human数量远多于bot，说明人类账号目前仍处于主导地位

# %%
import datetime
label=['2011-2015','2016-2020','2021-2024']
dat=[]
res1=0
res2=0
res3=0
leng=len(data['label'])
for i in range(0,leng):
    if data['label'][i]=='Bot':
        year=data['created_at'][i].year
        if year>=2011 and year<=2015:
            res1+=1
        elif year>=2016 and year<=2020:
            res2+=1
        elif year>=2021 and year<=2024:
            res3+=1
dat.append(res1)
dat.append(res2)
dat.append(res3)
plt.bar(label,dat)
plt.show()

# %%
#4.2
#将时间按年份分段，分为3个组，使用柱状图合适，发现2016-2020产生的bot多于2011-2015产生的bot，
#说明2016-2020 bot的产生效率比2011-2015更高，数据可能统计于2021年

# %%
import datetime
label=['2006-2010','2011-2015','2016-2020']
dat=[]
res1=0
res2=0
res3=0
leng=len(data['label'])
for i in range(0,leng):
    if data['label'][i]=='Human':
        year=data['created_at'][i].year
        if year>=2006 and year<=2010:
            res1+=1
        elif year>=2011 and year<=2015:
            res2+=1
        elif year>=2016 and year<=2020:
            res3+=1
dat.append(res1)
dat.append(res2)
dat.append(res3)
plt.bar(label,dat)
plt.show()

# %%
#4.3
#将时间按年份分段，分为3个组，使用柱状图合适，发现2016-2020产生的bot多于2011-2015产生的Human，
#说明2016-2020 Human账号数量可能逐步减少，数据可能于2009年开始

# %%
import datetime
label=['0-9','10-99','100-999','1000-9999']
dat=[]
res1=0
res2=0
res3=0
res4=0
leng=len(data['label'])
for i in range(0,leng):
    if data['label'][i]=='Bot':
        ff=data['followers'][i]
        if ff>=0 and ff<=9:
            res1+=1
        elif ff>=10 and ff<=99:
            res2+=1
        elif ff>=100 and ff<=999:
            res3+=1
        elif ff>=1000 and ff<=9999:
            res4+=1
dat.append(res1)
dat.append(res2)
dat.append(res3)
dat.append(res4)
plt.title("followers")
plt.bar(label,dat)
plt.show()

res1=0
res2=0
res3=0
res4=0
dat=[]
for i in range(0,leng):
    if data['label'][i]=='Bot':
        ff=data['following'][i]
        if ff>=0 and ff<=9:
            res1+=1
        elif ff>=10 and ff<=99:
            res2+=1
        elif ff>=100 and ff<=999:
            res3+=1
        elif ff>=1000 and ff<=9999:
            res4+=1
dat.append(res1)
dat.append(res2)
dat.append(res3)
dat.append(res4)
plt.title("following")
plt.bar(label,dat)
plt.show()

# %%
#4.4
#将人数分段，分为4个组，使用柱状图合适，发现随着（横坐标）人数增加following和followers的（纵坐标）人数显著减少，
#且followers分布更分散，following分布更集中0-9，
#说明大多数bot followers比following多

# %%
import datetime
label=['0-9','10-99','100-999','1000-9999']
dat=[]
res1=0
res2=0
res3=0
res4=0
leng=len(data['label'])
for i in range(0,leng):
    if data['label'][i]=='Human':
        ff=data['followers'][i]
        if ff>=0 and ff<=9:
            res1+=1
        elif ff>=10 and ff<=99:
            res2+=1
        elif ff>=100 and ff<=999:
            res3+=1
        elif ff>=1000 and ff<=9999:
            res4+=1
dat.append(res1)
dat.append(res2)
dat.append(res3)
dat.append(res4)
plt.title("followers")
plt.bar(label,dat)
plt.show()

res1=0
res2=0
res3=0
res4=0
dat=[]
for i in range(0,leng):
    if data['label'][i]=='Human':
        ff=data['following'][i]
        if ff>=0 and ff<=9:
            res1+=1
        elif ff>=10 and ff<=99:
            res2+=1
        elif ff>=100 and ff<=999:
            res3+=1
        elif ff>=1000 and ff<=9999:
            res4+=1
dat.append(res1)
dat.append(res2)
dat.append(res3)
dat.append(res4)
plt.title("following")
plt.bar(label,dat)
plt.show()

# %%
#4.5
#将人数分段，分为4个组，使用柱状图合适，发现随着（横坐标）人数增加following和followers的（纵坐标）人数显著减少，
#且followers分布更分散，following分布更集中0-9，
#说明大多数human followers比following多
